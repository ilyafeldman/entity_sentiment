# %%
from entity_sentiment import aspect_sentiment

# %%
import pandas as pd
import sqlite3

# %%
connection = sqlite3.connect(r'/Users/ilyafeldman/Desktop/Desktop/Coding/Codes/FLAP/news.db')
df = pd.read_sql_query("SELECT title , date , text FROM kaggle_news", connection)
df = df.head(20)

# %%
df
# Out:
#                                                 title        date  \
# 0   House Republicans Fret About Winning Their Hea...  2016-12-31
# 1   Rift Between Officers and Residents as Killing...  2017-06-19
# 2   Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...  2017-01-06
# 3   Among Deaths in 2016, a Heavy Toll in Pop Musi...  2017-04-10
# 4   Kim Jong-un Says North Korea Is Preparing to T...  2017-01-02
# 5   Sick With a Cold, Queen Elizabeth Misses New Y...  2017-01-02
# 6   Taiwan’s President Accuses China of Renewed In...  2017-01-02
# 7   After ‘The Biggest Loser,’ Their Bodies Fought...  2017-02-08
# 8   First, a Mixtape. Then a Romance. - The New Yo...  2016-12-31
# 9   Calling on Angels While Enduring the Trials of...  2016-12-31
# 10  Weak Federal Powers Could Limit Trump’s Climat...  2017-01-03
# 11  Can Carbon Capture Technology Prosper Under Tr...  2017-01-05
# 12  Mar-a-Lago, the Future Winter White House and ...  2017-01-02
# ...

# %%
result = aspect_sentiment(['North Korea'], df)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-10-12a2d4827a38> in <module>
# ----> 1 result = aspect_sentiment(['North Korea'], df)
#
# ~/Desktop/Desktop/Coding/Codes/Tests/entity_sentiment/entity_sentiment.py in aspect_sentiment(aspects, df)
#      96     if df.to_dict():
#      97         for text in df['text']:
# ---> 98             sentiment_result = compute(text, aspects)
#      99             for result in sentiment_result:
#     100                 score = sentiment_result[result]
#
# ~/Desktop/Desktop/Coding/Codes/Tests/entity_sentiment/entity_sentiment.py in compute(text, aspects)
#      89         aspect_classes = get_similar_words(noun_list, aspects)
#      90         #get sentiment
# ---> 91         sentiment_result = get_sentiment(aspect_classes, text)
#      92         return sentiment_result
#      93
#
# ...
